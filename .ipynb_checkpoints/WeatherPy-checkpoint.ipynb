# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# Importing API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Outputing file (csv)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Listing for holding lat_lngs and cities
lat_lngs = []
cities = []

# Creating a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identifying nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# cities = ["tilichiki", "london"]
# Printing the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={api_key}&units={units}&q='

# %%
i = 1
data = []
for city in cities:
    response = requests.get(query_url + city).json()
    if response['cod'] == 200:
        print(f"Processing city #{i}: {city}")
        data.append({
            'longitude': response['coord']['lon'], 
            'latitude': response['coord']['lat'],
            'temperature': response['main']['temp'],
            'humidity': response['main']['humidity'],
            'cloudiness': response['clouds']['all'],
            'wind speed': response['wind']['speed'],
            'city': response['name'],
            'country': response['sys']['country'],
            'date': response['dt']
        })
        i += 1
# Out:
# Processing city #1: oktyabrskiy
# Processing city #2: bluff
# Processing city #3: puerto ayora
# Processing city #4: geraldton
# Processing city #5: thompson
# Processing city #6: tessalit
# Processing city #7: lincoln
# Processing city #8: bitkine
# Processing city #9: bengkulu
# Processing city #10: cape town
# Processing city #11: najran
# Processing city #12: westport
# Processing city #13: praia
# Processing city #14: ponta do sol
# Processing city #15: grindavik
# Processing city #16: atuona
# Processing city #17: tiksi
# Processing city #18: nhulunbuy
# Processing city #19: hilo
# Processing city #20: kahului
# Processing city #21: altona
# Processing city #22: mahebourg
# Processing city #23: cherskiy
# Processing city #24: tateyama
# Processing city #25: sistranda
# Processing city #26: kieta
# Processing city #27: banda aceh
# Processing city #28: krasnoselkup
# Processing city #29: mattru
# Processing city #30: flinders
# Processing city #31: petatlan
# Processing city #32: rikitea
# Processing city #33: kruisfontein
# Processing city #34: baglan
# Processing city #35: asau
# Processing city #36: caucaia
# Processing city #37: lebu
# Processing city #38: honiara
# Processing city #39: bahia de caraquez
# Processing city #40: butaritari
# Processing city #41: ust-barguzin
# Processing city #42: albany
# Processing city #43: jolalpan
# Processing city #44: punta arenas
# Processing city #45: burns lake
# Processing city #46: poanas
# Processing city #47: hede
# Processing city #48: hasaki
# Processing city #49: nova vicosa
# Processing city #50: okhotsk
# Processing city #51: port alfred
# Processing city #52: berlevag
# Processing city #53: ushuaia
# Processing city #54: oranjemund
# Processing city #55: isangel
# Processing city #56: fortuna
# Processing city #57: maldonado
# Processing city #58: tuktoyaktuk
# Processing city #59: khasan
# Processing city #60: veraval
# Processing city #61: zhigansk
# Processing city #62: saint george
# Processing city #63: vao
# Processing city #64: narsaq
# Processing city #65: norman wells
# Processing city #66: vilhena
# Processing city #67: hobart
# Processing city #68: torbay
# Processing city #69: leku
# Processing city #70: noumea
# Processing city #71: airai
# Processing city #72: cayenne
# Processing city #73: pemangkat
# Processing city #74: carnarvon
# Processing city #75: gamba
# Processing city #76: neyshabur
# Processing city #77: tasiilaq
# Processing city #78: yellowknife
# Processing city #79: lazaro cardenas
# Processing city #80: hermanus
# Processing city #81: ouahigouya
# Processing city #82: soubre
# Processing city #83: avarua
# Processing city #84: missoula
# Processing city #85: komsomolskiy
# Processing city #86: kapaa
# Processing city #87: lanigan
# Processing city #88: leningradskiy
# Processing city #89: chernyshevskiy
# Processing city #90: jacqueville
# Processing city #91: castro
# Processing city #92: souillac
# Processing city #93: namibe
# Processing city #94: lorengau
# Processing city #95: salta
# Processing city #96: maunabo
# Processing city #97: busselton
# Processing city #98: vardo
# Processing city #99: madang
# Processing city #100: zabol
# Processing city #101: faanui
# Processing city #102: la ronge
# Processing city #103: gladstone
# Processing city #104: pacific grove
# Processing city #105: okahandja
# Processing city #106: saint-augustin
# Processing city #107: chokurdakh
# Processing city #108: jamestown
# Processing city #109: sehithwa
# Processing city #110: ornskoldsvik
# Processing city #111: port augusta
# Processing city #112: severo-kurilsk
# Processing city #113: chuy
# Processing city #114: rio grande
# Processing city #115: kavali
# Processing city #116: ust-kuyga
# Processing city #117: klaksvik
# Processing city #118: bandiagara
# Processing city #119: port elizabeth
# Processing city #120: saldanha
# Processing city #121: marsabit
# Processing city #122: hithadhoo
# Processing city #123: rio gallegos
# Processing city #124: aklavik
# Processing city #125: zenzeli
# Processing city #126: sekoma
# Processing city #127: macas
# Processing city #128: vaini
# Processing city #129: manati
# Processing city #130: cabedelo
# Processing city #131: council bluffs
# Processing city #132: mataura
# Processing city #133: gogapur
# Processing city #134: rijssen
# Processing city #135: dauriya
# Processing city #136: tarakan
# Processing city #137: lavrentiya
# Processing city #138: bredasdorp
# Processing city #139: guymon
# Processing city #140: ribeira grande
# Processing city #141: ponoka
# Processing city #142: porto belo
# Processing city #143: las vegas
# Processing city #144: la rioja
# Processing city #145: elizabeth city
# Processing city #146: cidreira
# Processing city #147: nome
# Processing city #148: aden
# Processing city #149: kanniyakumari
# Processing city #150: kasempa
# Processing city #151: nemuro
# Processing city #152: kavieng
# Processing city #153: izyum
# Processing city #154: saint-philippe
# Processing city #155: barrow
# Processing city #156: clyde river
# Processing city #157: galesong
# Processing city #158: lhokseumawe
# Processing city #159: alice springs
# Processing city #160: naze
# Processing city #161: puqi
# Processing city #162: denpasar
# Processing city #163: ust-tsilma
# Processing city #164: richards bay
# Processing city #165: qaanaaq
# Processing city #166: cootamundra
# Processing city #167: lipno
# Processing city #168: amapa
# Processing city #169: xifeng
# Processing city #170: meulaboh
# Processing city #171: bambous virieux
# Processing city #172: new norfolk
# Processing city #173: phalaborwa
# Processing city #174: constitucion
# Processing city #175: salalah
# Processing city #176: am timan
# Processing city #177: east london
# Processing city #178: tevaitoa
# Processing city #179: coquimbo
# Processing city #180: rawlins
# Processing city #181: loreto
# Processing city #182: iquique
# Processing city #183: arraial do cabo
# Processing city #184: jaque
# Processing city #185: talnakh
# Processing city #186: mar del plata
# Processing city #187: palmer
# Processing city #188: san patricio
# Processing city #189: longyearbyen
# Processing city #190: hargeysa
# Processing city #191: kemijarvi
# Processing city #192: pekan
# Processing city #193: itarema
# Processing city #194: arona
# Processing city #195: saint-leu
# Processing city #196: dikson
# Processing city #197: udachnyy
# Processing city #198: trincomalee
# Processing city #199: scurtu mare
# Processing city #200: suffolk
# Processing city #201: calabozo
# Processing city #202: erenhot
# Processing city #203: pesaro
# Processing city #204: kirakira
# Processing city #205: vila velha
# Processing city #206: srednekolymsk
# Processing city #207: shiyan
# Processing city #208: tahta
# Processing city #209: port macquarie
# Processing city #210: metaxades
# Processing city #211: katangli
# Processing city #212: san quintin
# Processing city #213: merauke
# Processing city #214: mporokoso
# Processing city #215: olinda
# Processing city #216: sept-iles
# Processing city #217: yumen
# Processing city #218: inegol
# Processing city #219: kangaatsiaq
# Processing city #220: kiruna
# Processing city #221: abonnema
# Processing city #222: tuatapere
# Processing city #223: hambantota
# Processing city #224: navlya
# Processing city #225: acapulco
# Processing city #226: bethel
# Processing city #227: kloulklubed
# Processing city #228: kaitangata
# Processing city #229: bacolod
# Processing city #230: pinczow
# Processing city #231: georgetown
# Processing city #232: muriwai beach
# Processing city #233: mareeba
# Processing city #234: mashhad
# Processing city #235: bratsk
# Processing city #236: provideniya
# Processing city #237: turukhansk
# Processing city #238: hirara
# Processing city #239: antofagasta
# Processing city #240: celestun
# Processing city #241: ancud
# Processing city #242: batagay
# Processing city #243: punta alta
# Processing city #244: mago
# Processing city #245: kozhva
# Processing city #246: mackenzie
# Processing city #247: morondava
# Processing city #248: suleja
# Processing city #249: gigmoto
# Processing city #250: nikolskoye
# Processing city #251: atar
# Processing city #252: lerwick
# Processing city #253: margate
# Processing city #254: lensk
# Processing city #255: valparaiso
# Processing city #256: port hedland
# Processing city #257: tenenkou
# Processing city #258: havoysund
# Processing city #259: zhangye
# Processing city #260: breves
# Processing city #261: garden city
# Processing city #262: paamiut
# Processing city #263: port hardy
# Processing city #264: manaus
# Processing city #265: fairbanks
# Processing city #266: middelburg
# Processing city #267: changde
# Processing city #268: harper
# Processing city #269: poco branco
# Processing city #270: chimbote
# Processing city #271: mathathane
# Processing city #272: fort nelson
# Processing city #273: rawson
# Processing city #274: abu zabad
# Processing city #275: port lincoln
# Processing city #276: algiers
# Processing city #277: ahipara
# Processing city #278: ulaanbaatar
# Processing city #279: forbes
# Processing city #280: alakurtti
# Processing city #281: resende
# Processing city #282: hokitika
# Processing city #283: lompoc
# Processing city #284: aguai
# Processing city #285: nara
# Processing city #286: guerrero negro
# Processing city #287: coahuayana
# Processing city #288: pangnirtung
# Processing city #289: bousso
# Processing city #290: kokopo
# Processing city #291: esperance
# Processing city #292: victoria
# Processing city #293: barranca
# Processing city #294: payo
# Processing city #295: lucea
# Processing city #296: pahrump
# Processing city #297: balingasay
# Processing city #298: aloleng
# Processing city #299: bathsheba
# Processing city #300: tiznit
# Processing city #301: pecos
# Processing city #302: merrill
# Processing city #303: san cristobal
# Processing city #304: faya
# Processing city #305: ridgecrest
# Processing city #306: charleston
# Processing city #307: coihaique
# Processing city #308: sosnytsya
# Processing city #309: bilibino
# Processing city #310: ebensee
# Processing city #311: punuare
# Processing city #312: port blair
# Processing city #313: massaguet
# Processing city #314: khatanga
# Processing city #315: indianola
# Processing city #316: ucluelet
# Processing city #317: ust-kalmanka
# Processing city #318: kodiak
# Processing city #319: itaqui
# Processing city #320: tazovskiy
# Processing city #321: castlerea
# Processing city #322: zlobin
# Processing city #323: yar-sale
# Processing city #324: morganton
# Processing city #325: khani
# Processing city #326: san andres
# Processing city #327: wanning
# Processing city #328: ermoupolis
# Processing city #329: saskylakh
# Processing city #330: kondrovo
# Processing city #331: arman
# Processing city #332: mamou
# Processing city #333: caravelas
# Processing city #334: beringovskiy
# Processing city #335: camacha
# Processing city #336: bandarbeyla
# Processing city #337: devarkonda
# Processing city #338: conway
# Processing city #339: upernavik
# Processing city #340: gorontalo
# Processing city #341: knysna
# Processing city #342: marrakesh
# Processing city #343: imphal
# Processing city #344: kamenskiy
# Processing city #345: lagoa
# Processing city #346: sola
# Processing city #347: kontagora
# Processing city #348: neuquen
# Processing city #349: dingle
# Processing city #350: ambilobe
# Processing city #351: olafsvik
# Processing city #352: bose
# Processing city #353: havre-saint-pierre
# Processing city #354: senanga
# Processing city #355: henties bay
# Processing city #356: yatou
# Processing city #357: patamundai
# Processing city #358: wuhan
# Processing city #359: mount gambier
# Processing city #360: kirgiz-miyaki
# Processing city #361: saint anthony
# Processing city #362: vilyuysk
# Processing city #363: sitka
# Processing city #364: mount pleasant
# Processing city #365: nelson bay
# Processing city #366: brae
# Processing city #367: beloha
# Processing city #368: auch
# Processing city #369: slave lake
# Processing city #370: luderitz
# Processing city #371: umm bab
# Processing city #372: calvinia
# Processing city #373: hof
# Processing city #374: chino valley
# Processing city #375: capreol
# Processing city #376: joetsu
# Processing city #377: katsuura
# Processing city #378: katobu
# Processing city #379: jiaojiang
# Processing city #380: jeremoabo
# Processing city #381: dawson creek
# Processing city #382: duma
# Processing city #383: gushikawa
# Processing city #384: macheng
# Processing city #385: grand gaube
# Processing city #386: pisco
# Processing city #387: takaungu
# Processing city #388: sao filipe
# Processing city #389: khilok
# Processing city #390: yara
# Processing city #391: codrington
# Processing city #392: pierre
# Processing city #393: puerto lempira
# Processing city #394: platanos
# Processing city #395: touros
# Processing city #396: inverness
# Processing city #397: namtsy
# Processing city #398: kysyl-syr
# Processing city #399: kastamonu
# Processing city #400: namatanai
# Processing city #401: zheleznodorozhnyy
# Processing city #402: buala
# Processing city #403: qinhuangdao
# Processing city #404: san carlos de bariloche
# Processing city #405: esperanza
# Processing city #406: botou
# Processing city #407: misratah
# Processing city #408: puerto leguizamo
# Processing city #409: berdigestyakh
# Processing city #410: kortkeros
# Processing city #411: vaitape
# Processing city #412: puerto rico
# Processing city #413: benemerito de las americas
# Processing city #414: vestmannaeyjar
# Processing city #415: omsukchan
# Processing city #416: pevek
# Processing city #417: neryungri
# Processing city #418: padang
# Processing city #419: cepu
# Processing city #420: omboue
# Processing city #421: la roda
# Processing city #422: gat
# Processing city #423: svetlyy
# Processing city #424: beni
# Processing city #425: sorland
# Processing city #426: marawi
# Processing city #427: tema
# Processing city #428: beyneu
# Processing city #429: necochea
# Processing city #430: george
# Processing city #431: lanzhou
# Processing city #432: ngunguru
# Processing city #433: cravo norte
# Processing city #434: kuusamo
# Processing city #435: nishihara
# Processing city #436: shingu
# Processing city #437: maarianhamina
# Processing city #438: dunedin
# Processing city #439: alexandria
# Processing city #440: tarauaca
# Processing city #441: bikaner
# Processing city #442: maues
# Processing city #443: sorong
# Processing city #444: mount isa
# Processing city #445: trairi
# Processing city #446: muros
# Processing city #447: camapua
# Processing city #448: saryagash
# Processing city #449: same
# Processing city #450: pochutla
# Processing city #451: vila franca do campo
# Processing city #452: vulcan
# Processing city #453: iqaluit
# Processing city #454: beruwala
# Processing city #455: mandera
# Processing city #456: marystown
# Processing city #457: sao gabriel da cachoeira
# Processing city #458: agulu
# Processing city #459: roald
# Processing city #460: villarrica
# Processing city #461: campbell river
# Processing city #462: fare
# Processing city #463: gold coast
# Processing city #464: dolinsk
# Processing city #465: luena
# Processing city #466: tazmalt
# Processing city #467: mopti
# Processing city #468: soyo
# Processing city #469: salina cruz
# Processing city #470: aasiaat
# Processing city #471: bella vista
# Processing city #472: osterburg
# Processing city #473: tarragona
# Processing city #474: santa maria
# Processing city #475: andilamena
# Processing city #476: peterhead
# Processing city #477: puerto suarez
# Processing city #478: wasco
# Processing city #479: ilulissat
# Processing city #480: hamilton
# Processing city #481: novikovo
# Processing city #482: klyuchi
# Processing city #483: mehamn
# Processing city #484: san jose
# Processing city #485: warrington
# Processing city #486: kununurra
# Processing city #487: gurupa
# Processing city #488: san policarpo
# Processing city #489: phan thiet
# Processing city #490: miyako
# Processing city #491: aranos
# Processing city #492: upington
# Processing city #493: broome
# Processing city #494: labuhan
# Processing city #495: pineville
# Processing city #496: trinidad
# Processing city #497: langsa
# Processing city #498: balan
# Processing city #499: dudinka
# Processing city #500: umm lajj
# Processing city #501: hualmay
# Processing city #502: ambon
# Processing city #503: muzhi
# Processing city #504: kunming
# Processing city #505: ginir
# Processing city #506: oga
# Processing city #507: zhezkazgan
# Processing city #508: yerbogachen
# Processing city #509: belyy yar
# Processing city #510: bubaque
# Processing city #511: hami
# Processing city #512: manggar
# Processing city #513: poum
# Processing city #514: jalu
# Processing city #515: husavik
# Processing city #516: don sak
# Processing city #517: zhireken
# Processing city #518: jatibonico
# Processing city #519: conde
# Processing city #520: kumluca
# Processing city #521: wasilla
# Processing city #522: ossora
# Processing city #523: bryan
# Processing city #524: tarskoye
# Processing city #525: cabo san lucas
# Processing city #526: ugoofaaru
# Processing city #527: babu
# Processing city #528: pasni
# Processing city #529: tsaratanana
# Processing city #530: aldan
# Processing city #531: karasburg
# Processing city #532: seoul
# Processing city #533: codajas
# Processing city #534: diamantino
# Processing city #535: talara
# Processing city #536: xining
# Processing city #537: sidi ali
# Processing city #538: ruteng
# Processing city #539: almora
# Processing city #540: coari
# Processing city #541: alofi
# Processing city #542: praia da vitoria
# Processing city #543: nabire
# Processing city #544: kavaratti
# Processing city #545: semey
# Processing city #546: sisimiut
# Processing city #547: buchanan
# Processing city #548: santa helena de goias
# Processing city #549: abapo
# Processing city #550: bahia blanca
# Processing city #551: asfi
# Processing city #552: jijiga
# Processing city #553: mulchen
# Processing city #554: los llanos de aridane
# Processing city #555: moranbah
# Processing city #556: muli
# Processing city #557: along
# Processing city #558: gravdal
# Processing city #559: milkovo
# Processing city #560: valdez
# Processing city #561: venado tuerto
# Processing city #562: salekhard
# Processing city #563: shitanjing
# Processing city #564: la seyne-sur-mer
# Processing city #565: nha trang
# Processing city #566: abja-paluoja
# Processing city #567: niceville
# Processing city #568: macouria
# Processing city #569: evensk
# Processing city #570: solihull
# Processing city #571: biloela
# Processing city #572: murray bridge
# Processing city #573: hanmer springs
# Processing city #574: aquiraz
# Processing city #575: worgl
# Processing city #576: geilo
# Processing city #577: dubai
# Processing city #578: jiujiang
# Processing city #579: karratha
# Processing city #580: nizwa
# Processing city #581: arlit
# Processing city #582: kawambwa
# Processing city #583: leshukonskoye
# Processing city #584: christchurch
# Processing city #585: mikulasovice
# Processing city #586: inhambane
# Processing city #587: eyl
# Processing city #588: bahia honda
# Processing city #589: yulara
# Processing city #590: sabya

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# DataFrame
df = pd.DataFrame(data)
df.to_csv('test.csv', index = False)
df.dtypes
# Out:
# city            object
# cloudiness       int64
# country         object
# date             int64
# humidity         int64
# latitude       float64
# longitude      float64
# temperature    float64
# wind speed     float64
# dtype: object

# %%
df.head()
# Out:
#            city  cloudiness country        date  humidity  latitude  \
# 0  Oktyabr'skiy         100      RU  1586837283        79     54.48
# 1         Bluff         100      NZ  1586837283        67    -46.60
# 2  Puerto Ayora         100      EC  1586837284        90     -0.74
# 3     Geraldton           3      AU  1586837284        47    -28.77
# 4      Thompson          20      CA  1586837001        64     55.74
#
#    longitude  temperature  wind speed
# 0      53.47         2.29        6.62
# 1     168.33         8.89        8.05
# 2     -90.35        26.11        2.24
# 3     114.60        26.50        7.70
# 4     -97.86       -17.00        1.50

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['temperature']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Temperature (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('images/Figure1LatitudeTemperature.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['humidity']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Humidity (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('images/Figure2LatitudeHumidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['cloudiness']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Cloudiness (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('images/Figure3LatitudeCloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['wind speed']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Wind Speed (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('images/Figure4LatitudeWindSpeed.png')
plt.show()

# %%
# Observation 1: Figure 1 shows a significant decrease as latitude increases.
# Observation 2: Figure 2 and Figure 4 show opposite correlations between humidity vs. latitude and wind speed vs. latitude.
# Observation 3: Figure 3 shows that there is no correlation between cloudiness and latitude.
