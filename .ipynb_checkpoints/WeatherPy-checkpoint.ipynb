# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output file (csv)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# cities = ["tilichiki", "london"]
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={api_key}&units={units}&q='

# %%
i = 1
data = []
for city in cities:
    response = requests.get(query_url + city).json()
    if response['cod'] == 200:
        print(f"Processing city #{i}: {city}")
        data.append({
            'longitude': response['coord']['lon'], 
            'latitude': response['coord']['lat'],
            'temperature': response['main']['temp'],
            'humidity': response['main']['humidity'],
            'cloudiness': response['clouds']['all'],
            'wind speed': response['wind']['speed'],
            'city': response['name'],
            'country': response['sys']['country'],
            'date': response['dt']
        })
        i += 1
# Out:
# Processing city #1: svencionys
# Processing city #2: busselton
# Processing city #3: rikitea
# Processing city #4: arraial do cabo
# Processing city #5: barrow
# Processing city #6: ushuaia
# Processing city #7: port alfred
# Processing city #8: bredasdorp
# Processing city #9: yellowknife
# Processing city #10: general nakar
# Processing city #11: qaqortoq
# Processing city #12: salalah
# Processing city #13: kuching
# Processing city #14: saint-philippe
# Processing city #15: mahibadhoo
# Processing city #16: new norfolk
# Processing city #17: lazaro cardenas
# Processing city #18: jamestown
# Processing city #19: sistranda
# Processing city #20: sao filipe
# Processing city #21: tuktoyaktuk
# Processing city #22: barabai
# Processing city #23: codrington
# Processing city #24: punta arenas
# Processing city #25: nouadhibou
# Processing city #26: cherskiy
# Processing city #27: east london
# Processing city #28: imeni poliny osipenko
# Processing city #29: thompson
# Processing city #30: puerto ayora
# Processing city #31: ouesso
# Processing city #32: mahebourg
# Processing city #33: rio grande
# Processing city #34: qaanaaq
# Processing city #35: souillac
# Processing city #36: faya
# Processing city #37: mar del plata
# Processing city #38: hilo
# Processing city #39: walvis bay
# Processing city #40: luderitz
# Processing city #41: hay river
# Processing city #42: avarua
# Processing city #43: san juan
# Processing city #44: oranjemund
# Processing city #45: san patricio
# Processing city #46: carnarvon
# Processing city #47: salihorsk
# Processing city #48: castro
# Processing city #49: albany
# Processing city #50: hithadhoo
# Processing city #51: caucaia
# Processing city #52: college
# Processing city #53: tommot
# Processing city #54: pierre
# Processing city #55: vaini
# Processing city #56: sinnamary
# Processing city #57: dalvik
# Processing city #58: the valley
# Processing city #59: kapaa
# Processing city #60: kahului
# Processing city #61: balsas
# Processing city #62: ziro
# Processing city #63: nabire
# Processing city #64: ahipara
# Processing city #65: thinadhoo
# Processing city #66: pingxiang
# Processing city #67: tlaltizapan
# Processing city #68: faanui
# Processing city #69: kaitangata
# Processing city #70: constitucion
# Processing city #71: karratha
# Processing city #72: seymchan
# Processing city #73: ribeira grande
# Processing city #74: alice springs
# Processing city #75: beloha
# Processing city #76: chuy
# Processing city #77: atuona
# Processing city #78: elblag
# Processing city #79: aswan
# Processing city #80: pangnirtung
# Processing city #81: nelson bay
# Processing city #82: alofi
# Processing city #83: airai
# Processing city #84: egvekinot
# Processing city #85: say
# Processing city #86: clyde river
# Processing city #87: morondava
# Processing city #88: tura
# Processing city #89: teguldet
# Processing city #90: verkhnevilyuysk
# Processing city #91: port elizabeth
# Processing city #92: bluff
# Processing city #93: cape town
# Processing city #94: biggar
# Processing city #95: hambantota
# Processing city #96: bozhou
# Processing city #97: mount gambier
# Processing city #98: narsaq
# Processing city #99: lompoc
# Processing city #100: coquimbo
# Processing city #101: fairbanks
# Processing city #102: rawlins
# Processing city #103: luba
# Processing city #104: phetchabun
# Processing city #105: tahoua
# Processing city #106: georgetown
# Processing city #107: charters towers
# Processing city #108: nikolskoye
# Processing city #109: lata
# Processing city #110: san rafael
# Processing city #111: ancud
# Processing city #112: butaritari
# Processing city #113: coahuayana
# Processing city #114: yar-sale
# Processing city #115: avera
# Processing city #116: san rafael del sur
# Processing city #117: port hedland
# Processing city #118: vila velha
# Processing city #119: hermanus
# Processing city #120: khatanga
# Processing city #121: maltahohe
# Processing city #122: beyneu
# Processing city #123: dubbo
# Processing city #124: qasigiannguit
# Processing city #125: trelew
# Processing city #126: marienburg
# Processing city #127: hualmay
# Processing city #128: tasiilaq
# Processing city #129: barraute
# Processing city #130: padang
# Processing city #131: marsh harbour
# Processing city #132: chokurdakh
# Processing city #133: kleive
# Processing city #134: tuatapere
# Processing city #135: lakes entrance
# Processing city #136: lumphat
# Processing city #137: biak
# Processing city #138: puerto escondido
# Processing city #139: mataura
# Processing city #140: dengzhou
# Processing city #141: conakry
# Processing city #142: lasa
# Processing city #143: pasighat
# Processing city #144: flinders
# Processing city #145: yafran
# Processing city #146: maragogi
# Processing city #147: chicama
# Processing city #148: vao
# Processing city #149: klaksvik
# Processing city #150: dingle
# Processing city #151: amapa
# Processing city #152: westport
# Processing city #153: geraldton
# Processing city #154: mao
# Processing city #155: ayna
# Processing city #156: artesia
# Processing city #157: hobart
# Processing city #158: williston
# Processing city #159: raudeberg
# Processing city #160: matara
# Processing city #161: mendi
# Processing city #162: nalut
# Processing city #163: jutai
# Processing city #164: honningsvag
# Processing city #165: springbok
# Processing city #166: saint george
# Processing city #167: nuuk
# Processing city #168: krasnotorka
# Processing city #169: roma
# Processing city #170: necochea
# Processing city #171: tchibanga
# Processing city #172: bandarbeyla
# Processing city #173: dikson
# Processing city #174: lorengau
# Processing city #175: gizo
# Processing city #176: yulara
# Processing city #177: yeniseysk
# Processing city #178: esperance
# Processing city #179: aykhal
# Processing city #180: masterton
# Processing city #181: pevek
# Processing city #182: mount juliet
# Processing city #183: muros
# Processing city #184: iskateley
# Processing city #185: mezen
# Processing city #186: segou
# Processing city #187: grindavik
# Processing city #188: dunedin
# Processing city #189: iqaluit
# Processing city #190: mendota
# Processing city #191: hasaki
# Processing city #192: sompeta
# Processing city #193: baramati
# Processing city #194: hofn
# Processing city #195: leh
# Processing city #196: half moon bay
# Processing city #197: upernavik
# Processing city #198: santa cruz
# Processing city #199: parauna
# Processing city #200: bacarra
# Processing city #201: otane
# Processing city #202: nanortalik
# Processing city #203: kamyshlov
# Processing city #204: kieta
# Processing city #205: alexandria
# Processing city #206: husavik
# Processing city #207: viseu
# Processing city #208: samfya
# Processing city #209: sabzevar
# Processing city #210: ponta do sol
# Processing city #211: antananarivo
# Processing city #212: dzhebariki-khaya
# Processing city #213: preobrazheniye
# Processing city #214: mumford
# Processing city #215: sagarejo
# Processing city #216: cayenne
# Processing city #217: carutapera
# Processing city #218: hohhot
# Processing city #219: saskylakh
# Processing city #220: saldanha
# Processing city #221: kodiak
# Processing city #222: bambous virieux
# Processing city #223: ilulissat
# Processing city #224: hounde
# Processing city #225: saint anthony
# Processing city #226: kutum
# Processing city #227: ascheberg
# Processing city #228: premia de mar
# Processing city #229: pimentel
# Processing city #230: kavaratti
# Processing city #231: lamesa
# Processing city #232: srednekolymsk
# Processing city #233: namibe
# Processing city #234: marawi
# Processing city #235: hobyo
# Processing city #236: longyearbyen
# Processing city #237: ambilobe
# Processing city #238: hovd
# Processing city #239: pandamatenga
# Processing city #240: paita
# Processing city #241: villanueva de la serena
# Processing city #242: dingzhou
# Processing city #243: norman wells
# Processing city #244: teshie
# Processing city #245: atherton
# Processing city #246: arman
# Processing city #247: cidreira
# Processing city #248: paratinga
# Processing city #249: balasheyka
# Processing city #250: cockburn town
# Processing city #251: razgrad
# Processing city #252: kasongo-lunda
# Processing city #253: broome
# Processing city #254: pervomayskoye
# Processing city #255: hamilton
# Processing city #256: kolosovka
# Processing city #257: oyama
# Processing city #258: isangel
# Processing city #259: lebu
# Processing city #260: slave lake
# Processing city #261: manta
# Processing city #262: houma
# Processing city #263: ambunti
# Processing city #264: bethel
# Processing city #265: novoagansk
# Processing city #266: limbe
# Processing city #267: huilong
# Processing city #268: leningradskiy
# Processing city #269: alugan
# Processing city #270: sur
# Processing city #271: khasan
# Processing city #272: ponta delgada
# Processing city #273: coihaique
# Processing city #274: goundi
# Processing city #275: little current
# Processing city #276: malayal
# Processing city #277: muisne
# Processing city #278: severo-kurilsk
# Processing city #279: pitimbu
# Processing city #280: cap malheureux
# Processing city #281: la ronge
# Processing city #282: homer
# Processing city #283: kloulklubed
# Processing city #284: iranshahr
# Processing city #285: kavieng
# Processing city #286: carupano
# Processing city #287: monte patria
# Processing city #288: tumalaytay
# Processing city #289: zolotyy potik
# Processing city #290: torrington
# Processing city #291: fortuna
# Processing city #292: portland
# Processing city #293: natal
# Processing city #294: provideniya
# Processing city #295: mount isa
# Processing city #296: itoman
# Processing city #297: micheweni
# Processing city #298: talnakh
# Processing city #299: fallbrook
# Processing city #300: sitka
# Processing city #301: lerwick
# Processing city #302: chippewa falls
# Processing city #303: zyryanka
# Processing city #304: dudinka
# Processing city #305: plettenberg bay
# Processing city #306: roald
# Processing city #307: batagay
# Processing city #308: barreirinhas
# Processing city #309: itacare
# Processing city #310: qinggang
# Processing city #311: payakumbuh
# Processing city #312: champawat
# Processing city #313: muroto
# Processing city #314: banihal
# Processing city #315: podkletnoye
# Processing city #316: manadhoo
# Processing city #317: nioro
# Processing city #318: hami
# Processing city #319: tshela
# Processing city #320: gigmoto
# Processing city #321: oktyabrskiy
# Processing city #322: port macquarie
# Processing city #323: hengyang
# Processing city #324: rocha
# Processing city #325: ambulu
# Processing city #326: tiksi
# Processing city #327: anloga
# Processing city #328: dali
# Processing city #329: el dorado
# Processing city #330: solnechnyy
# Processing city #331: champerico
# Processing city #332: otavi
# Processing city #333: warwick
# Processing city #334: itarema
# Processing city #335: hoquiam
# Processing city #336: goure
# Processing city #337: los llanos de aridane
# Processing city #338: atasu
# Processing city #339: victoria
# Processing city #340: damaturu
# Processing city #341: caravelas
# Processing city #342: richards bay
# Processing city #343: dzhida
# Processing city #344: palana
# Processing city #345: kibala
# Processing city #346: jalapa
# Processing city #347: taltal
# Processing city #348: hermagor
# Processing city #349: mhlume
# Processing city #350: fernley
# Processing city #351: namatanai
# Processing city #352: mecca
# Processing city #353: jardim
# Processing city #354: bhainsa
# Processing city #355: praxedis guerrero
# Processing city #356: igarka
# Processing city #357: sola
# Processing city #358: zhovkva
# Processing city #359: northam
# Processing city #360: ponerihouen
# Processing city #361: praia
# Processing city #362: chabahar
# Processing city #363: meulaboh
# Processing city #364: grand-santi
# Processing city #365: opuwo
# Processing city #366: irbit
# Processing city #367: resistencia
# Processing city #368: feijo
# Processing city #369: kruisfontein
# Processing city #370: abu samrah
# Processing city #371: vanavara
# Processing city #372: tezu
# Processing city #373: varhaug
# Processing city #374: san quintin
# Processing city #375: sangueya
# Processing city #376: port hardy
# Processing city #377: vasto
# Processing city #378: vagay
# Processing city #379: inuvik
# Processing city #380: san buenaventura
# Processing city #381: progreso
# Processing city #382: amuntai
# Processing city #383: naze
# Processing city #384: bari
# Processing city #385: skjervoy
# Processing city #386: lebanon
# Processing city #387: chino valley
# Processing city #388: nizhniy kuranakh
# Processing city #389: klyuchi
# Processing city #390: takoradi
# Processing city #391: beian
# Processing city #392: sambava
# Processing city #393: hatten
# Processing city #394: zhangjiakou
# Processing city #395: tazovskiy
# Processing city #396: luanda
# Processing city #397: popova
# Processing city #398: arco
# Processing city #399: cedar city
# Processing city #400: dabola
# Processing city #401: tyukhtet
# Processing city #402: hokitika
# Processing city #403: vestmannaeyjar
# Processing city #404: betare oya
# Processing city #405: trapani
# Processing city #406: warrnambool
# Processing city #407: fare
# Processing city #408: sabha
# Processing city #409: waingapu
# Processing city #410: wagga wagga
# Processing city #411: guerrero negro
# Processing city #412: dharchula
# Processing city #413: isla mujeres
# Processing city #414: el jicaro
# Processing city #415: hirara
# Processing city #416: saint-joseph
# Processing city #417: vardo
# Processing city #418: bilibino
# Processing city #419: kysyl-syr
# Processing city #420: pelotas
# Processing city #421: havoysund
# Processing city #422: sorong
# Processing city #423: esso
# Processing city #424: birjand
# Processing city #425: kovdor
# Processing city #426: trinec
# Processing city #427: edinet
# Processing city #428: harper
# Processing city #429: omsukchan
# Processing city #430: bongandanga
# Processing city #431: sri aman
# Processing city #432: kangaba
# Processing city #433: venado tuerto
# Processing city #434: rawson
# Processing city #435: lazurne
# Processing city #436: gilbues
# Processing city #437: lavrentiya
# Processing city #438: el vigia
# Processing city #439: pisco
# Processing city #440: emerald
# Processing city #441: quelimane
# Processing city #442: sivaki
# Processing city #443: maralal
# Processing city #444: south lake tahoe
# Processing city #445: komsomolskiy
# Processing city #446: hervey bay
# Processing city #447: vallenar
# Processing city #448: zeya
# Processing city #449: aksarka
# Processing city #450: bismarck
# Processing city #451: buala
# Processing city #452: pangody
# Processing city #453: nautanwa
# Processing city #454: abu kamal
# Processing city #455: huoqiu
# Processing city #456: huarmey
# Processing city #457: nome
# Processing city #458: marystown
# Processing city #459: toamasina
# Processing city #460: ucluelet
# Processing city #461: manaus
# Processing city #462: carberry
# Processing city #463: oyem
# Processing city #464: superior
# Processing city #465: namie
# Processing city #466: dale
# Processing city #467: broken hill
# Processing city #468: hudson bay
# Processing city #469: ulety
# Processing city #470: belaya gora
# Processing city #471: zapolyarnyy
# Processing city #472: zhezkazgan
# Processing city #473: mackay
# Processing city #474: touros
# Processing city #475: mandalgovi
# Processing city #476: magaria
# Processing city #477: pocone
# Processing city #478: santa pola
# Processing city #479: canakkale
# Processing city #480: buraydah
# Processing city #481: konakovo
# Processing city #482: ugoofaaru
# Processing city #483: jalu
# Processing city #484: santa maria
# Processing city #485: ozernovskiy
# Processing city #486: erzin
# Processing city #487: sao miguel
# Processing city #488: chipinge
# Processing city #489: cap-aux-meules
# Processing city #490: tukums
# Processing city #491: palmer
# Processing city #492: viedma
# Processing city #493: comodoro rivadavia
# Processing city #494: butembo
# Processing city #495: sidi ali
# Processing city #496: makakilo city
# Processing city #497: tortoli
# Processing city #498: goderich
# Processing city #499: bela
# Processing city #500: jiwani
# Processing city #501: balkanabat
# Processing city #502: guilin
# Processing city #503: jever
# Processing city #504: istanbul
# Processing city #505: fremont
# Processing city #506: tingloy
# Processing city #507: sakata
# Processing city #508: newton
# Processing city #509: fougamou
# Processing city #510: kaeo
# Processing city #511: marsabit
# Processing city #512: abu dhabi
# Processing city #513: itaituba
# Processing city #514: ligayan
# Processing city #515: marivan
# Processing city #516: yumen
# Processing city #517: noumea
# Processing city #518: seydi
# Processing city #519: vanimo
# Processing city #520: oga
# Processing city #521: potiskum
# Processing city #522: bijar
# Processing city #523: lhokseumawe
# Processing city #524: aden
# Processing city #525: kushima
# Processing city #526: galveston
# Processing city #527: jian
# Processing city #528: somovo
# Processing city #529: bougouni
# Processing city #530: deputatskiy
# Processing city #531: oriximina
# Processing city #532: hatillo
# Processing city #533: petropavlovsk-kamchatskiy
# Processing city #534: tete
# Processing city #535: yerbogachen
# Processing city #536: verkhoyansk
# Processing city #537: beringovskiy
# Processing city #538: general roca
# Processing city #539: smithers
# Processing city #540: moussoro
# Processing city #541: merauke
# Processing city #542: pleasanton
# Processing city #543: mildura
# Processing city #544: rincon
# Processing city #545: sandovo
# Processing city #546: gwanda
# Processing city #547: tambo grande
# Processing city #548: topalu
# Processing city #549: rockingham
# Processing city #550: nisia floresta
# Processing city #551: vidim
# Processing city #552: guatire
# Processing city #553: sucua
# Processing city #554: moramanga
# Processing city #555: gandajika
# Processing city #556: litovko
# Processing city #557: acari
# Processing city #558: taoudenni

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# DataFrame
df = pd.DataFrame(data)
df.to_csv('test.csv', index = False)
df.dtypes
# Out:
# city            object
# cloudiness       int64
# country         object
# date             int64
# humidity         int64
# latitude       float64
# longitude      float64
# temperature    float64
# wind speed     float64
# dtype: object

# %%
df.head()
# Out:
#               city  cloudiness country        date  humidity  latitude  \
# 0       Svencionys          39      LT  1578442266        92     55.15
# 1        Busselton          27      AU  1578442266        69    -33.64
# 2          Rikitea          11      PF  1578442266        77    -23.12
# 3  Arraial do Cabo          20      BR  1578442266        83    -22.97
# 4           Barrow           0      AR  1578442266        44    -38.31
#
#    longitude  temperature  wind speed
# 0      26.17        -1.64        2.88
# 1     115.35        21.33        0.45
# 2    -134.97        25.37        8.43
# 3     -42.02        27.00        1.50
# 4     -60.23        19.73        4.40

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['temperature']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Temperature (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('images/Figure1LatitudeTemperature.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['humidity']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Humidity (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('images/Figure2LatitudeHumidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['cloudiness']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Cloudiness (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('images/Figure3LatitudeCloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plotting
for dat in data:
    x = dat['latitude']
    y = dat['wind speed']
    plt.scatter(x, y, alpha = 0.5)
plt.title('City Latitude vs. Wind Speed (1/7/2020)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('images/Figure4LatitudeWindSpeed.png')
plt.show()

# %%
# Observation 1: Figure 1 shows a significant decrease as latitude increases.
# Observation 2: Figure 2 and Figure 4 show opposite correlations between humidity vs. latitude and wind speed vs. latitude.
# Observation 3: Figure 3 shows that there is no correlation between cloudiness and latitude.
